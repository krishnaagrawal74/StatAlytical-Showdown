# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
file_path = 'statalyticalshowdownCSV.csv'  
df = pd.read_csv(file_path)

# %% [markdown]
# ## To check whether null values present

# %%
print("Missing Values in Each Column:")
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Missing Values in Each Column:
# Administrative             0
# Administrative_Duration    0
# Informational              0
# Informational_Duration     0
# ProductRelated             0
# ProductRelated_Duration    0
# BounceRates                0
# ExitRates                  0
# PageValues                 0
# SpecialDay                 0
# Month                      0
# OperatingSystems           0
# Browser                    0
# Region                     0
# TrafficType                0
# VisitorType                0
# Weekend                    0
# Revenue                    0
# dtype: int64

# %% [markdown]
# ## 	Distribution of Data: Examining the distribution of data points to understand their range, central tendencies (mean,median,mode) and dispersion (variance, standard deviation).

# %%
numerical_cols = df.select_dtypes(include=[np.number]).columns #columns which contain numerical values
print("Range, Central Tendencies and Dispersion of the Columns in the Dataset:")
for col in numerical_cols:
    print()
    print(f"{col}:")
    print(f"Mean: {df[col].mean():.2f}")
    print(f"Median: {df[col].median():.2f}")
    print(f"Mode: {df[col].mode()[0]:.2f}")
    print(f"Variance: {df[col].var():.2f}")
    print(f"Standard Deviation: {df[col].std():.2f}")
    print(f"Range: {df[col].min():.2f} - {df[col].max():.2f}")

# Plotting the distribution for visualisation
for col in numerical_cols:
    plt.figure(figsize=(7, 4))
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# Range, Central Tendencies and Dispersion of the Columns in the Dataset:
#
# Administrative:
# Mean: 2.32
# Median: 1.00
# Mode: 0.00
# Variance: 11.03
# Standard Deviation: 3.32
# Range: 0.00 - 27.00
#
# Administrative_Duration:
# Mean: 80.82
# Median: 7.50
# Mode: 0.00
# Variance: 31250.85
# Standard Deviation: 176.78
# Range: 0.00 - 3398.75
#
# Informational:
# Mean: 0.50
# Median: 0.00
# Mode: 0.00
# Variance: 1.61
# Standard Deviation: 1.27
# Range: 0.00 - 24.00
#
# Informational_Duration:
# Mean: 34.47
# Median: 0.00
# Mode: 0.00
# Variance: 19810.36
# Standard Deviation: 140.75
# Range: 0.00 - 2549.38
#
# ProductRelated:
# Mean: 31.73
# Median: 18.00
# Mode: 1.00
# Variance: 1978.07
# Standard Deviation: 44.48
# Range: 0.00 - 705.00
#
# ProductRelated_Duration:
# Mean: 1194.75
# Median: 598.94
# Mode: 0.00
# Variance: 3662130.14
# Standard Deviation: 1913.67
# Range: 0.00 - 63973.52
#
# BounceRates:
# Mean: 0.02
# Median: 0.00
# Mode: 0.00
# Variance: 0.00
# Standard Deviation: 0.05
# Range: 0.00 - 0.20
#
# ExitRates:
# Mean: 0.04
# Median: 0.03
# Mode: 0.20
# Variance: 0.00
# Standard Deviation: 0.05
# Range: 0.00 - 0.20
#
# PageValues:
# Mean: 5.89
# Median: 0.00
# Mode: 0.00
# Variance: 344.79
# Standard Deviation: 18.57
# Range: 0.00 - 361.76
#
# SpecialDay:
# Mean: 0.06
# Median: 0.00
# Mode: 0.00
# Variance: 0.04
# Standard Deviation: 0.20
# Range: 0.00 - 1.00

# %%
# Function to detect outliers
def detect_outliers(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)][column]
    return outliers
print("Outliers in the columns of dataset:")
print()
for col in numerical_cols:
    outliers = detect_outliers(df, col)
    print(f"{col}: {len(outliers)} outliers")
    if not outliers.empty:
        print(f"Sample outliers: {outliers.head().tolist()}")
    print()

# Visualizing outliers with boxplots
for col in numerical_cols:
    plt.figure(figsize=(7, 4))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col} (Outliers)')
    plt.show()
# Out:
# Outliers in the columns of dataset:
#
# Administrative: 404 outliers
# Sample outliers: [12, 16, 13, 11, 13]
#
# Administrative_Duration: 1172 outliers
# Sample outliers: [279.4166667, 1005.666667, 326.25, 462.0, 293.7782051]
#
# Informational: 2631 outliers
# Sample outliers: [1, 2, 1, 1, 1]
#
# Informational_Duration: 2405 outliers
# Sample outliers: [120.0, 16.0, 94.0, 93.0, 75.0]
#
# ProductRelated: 987 outliers
# Sample outliers: [90, 128, 96, 98, 87]
#
# ProductRelated_Duration: 961 outliers
# Sample outliers: [4084.393939, 6951.972222, 5062.213753, 3556.61241, 5188.5]
#
# BounceRates: 1551 outliers
# Sample outliers: [0.2, 0.2, 0.05, 0.2, 0.2]
#
# ExitRates: 1099 outliers
# Sample outliers: [0.2, 0.2, 0.14, 0.2, 0.2]
#
# PageValues: 2730 outliers
# Sample outliers: [54.17976426, 19.44707913, 38.30849268, 22.9160357, 11.43941195]
#
# SpecialDay: 1251 outliers
# Sample outliers: [0.4, 0.8, 0.4, 0.4, 1.0]

# %%
# Compute correlation matrix
correlation_matrix = df[numerical_cols].corr()
# note that this matrix uses pearson correlation coefficients

print("\nCorrelation Matrix - Pearson Correlation Coefficients")
print(correlation_matrix)

# Visualizing the matrix with heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='seismic', vmin=-1, vmax=1, fmt='.2f')
plt.title('Correlation Matrix')
plt.show()
# Out:
# Correlation Matrix - Pearson Correlation Coefficients
#                          Administrative  Administrative_Duration  \
# Administrative                 1.000000                 0.601583
# Administrative_Duration        0.601583                 1.000000
# Informational                  0.376850                 0.302710
# Informational_Duration         0.255848                 0.238031
# ProductRelated                 0.431119                 0.289087
# ProductRelated_Duration        0.373939                 0.355422
# BounceRates                   -0.223563                -0.144170
# ExitRates                     -0.316483                -0.205798
# PageValues                     0.098990                 0.067608
# SpecialDay                    -0.094778                -0.073304
#
#                          Informational  Informational_Duration  \
# Administrative                0.376850                0.255848
# Administrative_Duration       0.302710                0.238031
# Informational                 1.000000                0.618955
# Informational_Duration        0.618955                1.000000
# ProductRelated                0.374164                0.280046
# ProductRelated_Duration       0.387505                0.347364
# BounceRates                  -0.116114               -0.074067
# ExitRates                    -0.163666               -0.105276
# PageValues                    0.048632                0.030861
# SpecialDay                   -0.048219               -0.030577
#
#                          ProductRelated  ProductRelated_Duration  BounceRates  \
# Administrative                 0.431119                 0.373939    -0.223563
# Administrative_Duration        0.289087                 0.355422    -0.144170
# Informational                  0.374164                 0.387505    -0.116114
# Informational_Duration         0.280046                 0.347364    -0.074067
# ProductRelated                 1.000000                 0.860927    -0.204578
# ProductRelated_Duration        0.860927                 1.000000    -0.184541
# BounceRates                   -0.204578                -0.184541     1.000000
# ExitRates                     -0.292526                -0.251984     0.913004
# PageValues                     0.056282                 0.052823    -0.119386
# SpecialDay                    -0.023958                -0.036380     0.072702
#
#                          ExitRates  PageValues  SpecialDay
# Administrative           -0.316483    0.098990   -0.094778
# Administrative_Duration  -0.205798    0.067608   -0.073304
# Informational            -0.163666    0.048632   -0.048219
# Informational_Duration   -0.105276    0.030861   -0.030577
# ProductRelated           -0.292526    0.056282   -0.023958
# ProductRelated_Duration  -0.251984    0.052823   -0.036380
# BounceRates               0.913004   -0.119386    0.072702
# ExitRates                 1.000000   -0.174498    0.102242
# PageValues               -0.174498    1.000000   -0.063541
# SpecialDay                0.102242   -0.063541    1.000000

# %%
# summary for numerical data
print("\nSummary Statistics - Numerical Data:")
print(df[numerical_cols].describe())

# summary for categorical data
categorical_cols = df.select_dtypes(include=['object', 'bool']).columns
print("\nCategorical Value Counts:")
for col in categorical_cols:
    print()
    print(df[col].value_counts().to_string())
# Out:
# Summary Statistics - Numerical Data:
#        Administrative  Administrative_Duration  Informational  \
# count    12330.000000             12330.000000   12330.000000
# mean         2.315166                80.818611       0.503569
# std          3.321784               176.779107       1.270156
# min          0.000000                 0.000000       0.000000
# 25%          0.000000                 0.000000       0.000000
# 50%          1.000000                 7.500000       0.000000
# 75%          4.000000                93.256250       0.000000
# max         27.000000              3398.750000      24.000000
#
#        Informational_Duration  ProductRelated  ProductRelated_Duration  \
# count            12330.000000    12330.000000             12330.000000
# mean                34.472398       31.731468              1194.746220
# std                140.749294       44.475503              1913.669288
# min                  0.000000        0.000000                 0.000000
# 25%                  0.000000        7.000000               184.137500
# 50%                  0.000000       18.000000               598.936905
# 75%                  0.000000       38.000000              1464.157214
# max               2549.375000      705.000000             63973.522230
#
#         BounceRates     ExitRates    PageValues    SpecialDay
# count  12330.000000  12330.000000  12330.000000  12330.000000
# mean       0.022191      0.043073      5.889258      0.061427
# std        0.048488      0.048597     18.568437      0.198917
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.014286      0.000000      0.000000
# 50%        0.003112      0.025156      0.000000      0.000000
# 75%        0.016813      0.050000      0.000000      0.000000
# max        0.200000      0.200000    361.763742      1.000000
#
# Categorical Value Counts:
#
# Month
# May     3364
# Nov     2998
# Mar     1907
# Dec     1727
# Oct      549
# Sep      448
# Aug      433
# Jul      432
# June     288
# Feb      184
#
# OperatingSystems
# macOS      6601
# Windows    2585
# Linux      2555
# Android     478
# Debian       79
# Ubuntu       19
# Fedora        7
# iOS           6
#
# Browser
# Firefox              7961
# Chrome               2462
# Edge                  736
# Opera                 467
# Brave                 174
# UC Browser            163
# Internet Explorer     135
# Safari                105
# Pale Moon              61
# Vivaldi                49
# SeaMonkey              10
# Maxthon                 6
# Tor Browser             1
#
# Region
# Delhi        4780
# Kolkata      2403
# Bangalore    1182
# Mumbai       1136
# Hyderabad     805
# Ahmedabad     761
# Pune          511
# Surat         434
# Chennai       318
#
# TrafficType
# Organic Search Traffic              3913
# Direct Traffic                      2451
# Paid Search Traffic                 2052
# Referral Traffic                    1069
# Podcast Traffic                      738
# Video Marketing Traffic              450
# Email Traffic                        444
# Affiliate Marketing Traffic          343
# Social Media Traffic                 260
# Content Marketing Traffic            247
# Community Traffic                    198
# Influencer Marketing Traffic          42
# Display Advertising Traffic           40
# Push Notification Traffic             38
# Forum Traffic                         17
# SMS Marketing Traffic                 13
# Guest Blogging Traffic                10
# Retargeting Traffic                    3
# Mobile App Traffic                     1
# Influencer Collaboration Traffic       1
#
# VisitorType
# Returning_Visitor    10551
# New_Visitor           1694
# Other                   85
#
# Weekend
# False    9462
# True     2868
#
# Revenue
# False    10422
# True      1908

# %%
print("Shapiro-Wilk Normality Test:\n")
for col in numerical_cols:
    stat, p = stats.shapiro(df[col])
    print(f"{col}: Statistic={stat:.3f}, p-value={p:.3f}")
    if p > 0.05:
        print(f"  -> Appears normally distributed") # p-value > 0.05 suggests normal distribution
        print()
    else:
        print(f"  -> Not normally distributed")
        print()
# Out:
# Shapiro-Wilk Normality Test:
#
# Administrative: Statistic=0.734, p-value=0.000
#   -> Not normally distributed
#
# Administrative_Duration: Statistic=0.482, p-value=0.000
#   -> Not normally distributed
#
# Informational: Statistic=0.458, p-value=0.000
#   -> Not normally distributed
#
# Informational_Duration: Statistic=0.260, p-value=0.000
#   -> Not normally distributed
#
# ProductRelated: Statistic=0.610, p-value=0.000
#   -> Not normally distributed
#
# ProductRelated_Duration: Statistic=0.555, p-value=0.000
#   -> Not normally distributed
#
# BounceRates: Statistic=0.492, p-value=0.000
#   -> Not normally distributed
#
# ExitRates: Statistic=0.699, p-value=0.000
#   -> Not normally distributed
#
# PageValues: Statistic=0.355, p-value=0.000
#   -> Not normally distributed
#
# SpecialDay: Statistic=0.343, p-value=0.000
#   -> Not normally distributed
